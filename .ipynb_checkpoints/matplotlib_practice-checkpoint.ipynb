# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#skilldrill pie chart with object oriented
fig, ax = plt.subplots(figsize=(8, 8))
colors=["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, labels=x_axis, autopct='%1.f%%', colors=colors, explode=explode_values, shadow=True, counterclock=False, startangle=100)
plt.show()

# %%
# create a pie chart using MATLAB
plt.pie(y_axis, labels=x_axis)

plt.show()

# %%
plt.subplots(figsize=(8, 8))
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, colors=colors, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
#Change the color of the markers to sky blue.
#Make the color 20% transparent.
#Add a black edge color to the circles.
#Change the size of the markers to 5 times each data point.
#Make the linewidth of the circles 2 points.
#Switch the axis so that the Fare($) data is on the x-axis.

fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, s=[i*10 for i in y_axis], color="skyblue", alpha=0.8, edgecolor="black", linewidth=2, label="Boston")

#Add a legend for the city of Boston.
ax.legend()
#Add a title.
ax.set_title("PyBer Fare by Month")

#Add a limit for the x-axis data.
ax.set_xlim(0, 50)
#Invert the y-axis so that January is at the top.
ax.invert_yaxis()

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
#Change the color of the markers to red.
#Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis, x_axis, c="red", label="Chicago")
#Add a legend for the city of Chicago.
plt.legend()
#Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")

#Add a limit for the x-axis data.
plt.xlim(0, 50)
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
#Change the bar colors to magenta.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")


#Add a legend for the city of Boston.
plt.legend()
#Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")

#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Change the bar color to cyan.
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Chicago")
#Add a legend for the city of Chicago.
ax.legend()
#Add a title and axes labels.
ax.set_title('PyBer Fare by Month')
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
#Switch the axis so that the Fare($) data is on the x-axis.

#Invert the y-axis data.
ax.invert_yaxis()

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
fig, ax = plt.subplots()
#Change the line color to green.
#Change the marker to a diamond.
#Change the line width to 2 points.
ax.plot(x_axis, y_axis, marker="d", color="green", linewidth=2, label='Boston')
#Add a legend for the city of Boston.
ax.legend()
#Add a title and axes labels.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
#Add a y-axis limit.
ax.set_ylim(0, 45)
#Add grid lines.
ax.grid()
plt.savefig("add a path and figure extension")

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()
